# %%
# Import Libraries
## Standard Libraries
import datetime
import json

## Third-Party Libraries
import pandas as pd

## Local Libraries
from v2.scraper import LiveMatchScraper, MatchRecordsScraper, TeamIDScraper

# %% [markdown]
# ## 1. Test Query for Team IDs

# %%
team_id_scraper = TeamIDScraper()
team_id_dict = team_id_scraper.get_team_ids()
team_info_df = pd.DataFrame(team_id_dict["data"]["teamList"])
team_info_df.head()
# Out:
#          id code  name_ch             name_en
# 0  50000001  TMN  1860慕尼黑         1860 Munich
# 1  50000002  OCT     十月九日        9 de Octubre
# 2  50000003  AAS    澳職明星隊  A-League All Stars
# 3  50000004  AAG       真特             AA Gent
# 4  50362134  GTW     真特女足       AA Gent Women

# %%
team_info_df.loc[team_info_df["name_en"] == "Real Madrid"]
# Out:
#             id code name_ch      name_en
# 3612  50002589  RMD   皇家馬德里  Real Madrid

# %% [markdown]
# ## 2. Test Query for Historical Matches

# %%
match_records_scraper = MatchRecordsScraper()
match_records_list = match_records_scraper.get_historical_matches(
    start_date=datetime.date(2024, 11, 1),
    end_date=datetime.date(2025, 1, 23),
    team_id="50002589",
)

# %%
len(match_records_list)
# Out:
# 18

# %%
match_records_list[0].keys()
# Out:
# dict_keys(['id', 'status', 'frontEndId', 'matchDayOfWeek', 'matchNumber', 'matchDate', 'kickOffTime', 'sequence', 'homeTeam', 'awayTeam', 'tournament', 'results', 'poolInfo'])

# %%
with open("../../../data/sample_data/match_records_real_madrid_sample_20250124.json", "w") as f:
    f.write(json.dumps(match_records_list))

# %% [markdown]
# ## 3. Test Query for Match Results

# %%
match_result = match_records_scraper.get_match_result_by_match_id(
    match_id="50039609",
)
match_result
# Out:
# {'id': '50039609',
#  'foPools': [{'id': '826156044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 16,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '西維爾半場勝 & 皇家馬德里全場淨勝[2]球或以上',
#          'name_en': 'Sevilla to win the first half & Real Madrid to win the match by [2] goal(s) or more'}]}]}]},
#   {'id': '828029015',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'NTS',
#    'instNo': 5,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊',
#          'name_en': 'Away'}]},
#       {'str': 'N',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': 'N',
#          'name_ch': '無入球',
#          'name_en': 'No Goals'}]}]}]},
#   {'id': '826146044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 6,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '全場兩隊均取得入球 & 半場和 & 皇家馬德里全場淨勝[2]球或以上',
#          'name_en': 'Both teams to score in the match & First Half to be drawn & Real Madrid to win the match by [2] goal(s) or more'}]}]}]},
#   {'id': '826152044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 12,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '半場開出總角球少於[3.5]球 & 全場開出總角球少於[8.5]球',
#          'name_en': 'Under [3.5] corners taken in the first half & Under [8.5] corners taken in the match'}]}]}]},
#   {'id': '813792009',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'CRS',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': '01:00',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '1:0',
#          'name_ch': '1:0',
#          'name_en': '1:0'}]},
#       {'str': '02:00',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': '2:0',
#          'name_ch': '2:0',
#          'name_en': '2:0'}]},
#       {'str': '02:01',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': '2:1',
#          'name_ch': '2:1',
#          'name_en': '2:1'}]},
#       {'str': '03:00',
#        'status': 'LOSE',
#        'winOrd': '4',
#        'selections': [{'selId': '4',
#          'str': '3:0',
#          'name_ch': '3:0',
#          'name_en': '3:0'}]},
#       {'str': '03:01',
#        'status': 'LOSE',
#        'winOrd': '5',
#        'selections': [{'selId': '5',
#          'str': '3:1',
#          'name_ch': '3:1',
#          'name_en': '3:1'}]},
#       {'str': '03:02',
#        'status': 'LOSE',
#        'winOrd': '6',
#        'selections': [{'selId': '6',
#          'str': '3:2',
#          'name_ch': '3:2',
#          'name_en': '3:2'}]},
#       {'str': '04:00',
#        'status': 'LOSE',
#        'winOrd': '7',
#        'selections': [{'selId': '7',
#          'str': '4:0',
#          'name_ch': '4:0',
#          'name_en': '4:0'}]},
#       {'str': '04:01',
#        'status': 'LOSE',
#        'winOrd': '8',
#        'selections': [{'selId': '8',
#          'str': '4:1',
#          'name_ch': '4:1',
#          'name_en': '4:1'}]},
#       {'str': '04:02',
#        'status': 'WIN',
#        'winOrd': '9',
#        'selections': [{'selId': '9',
#          'str': '4:2',
#          'name_ch': '4:2',
#          'name_en': '4:2'}]},
#       {'str': '03:03',
#        'status': 'LOSE',
#        'winOrd': '32',
#        'selections': [{'selId': '30',
#          'str': '3:3',
#          'name_ch': '3:3',
#          'name_en': '3:3'}]},
#       {'str': 'DO',
#        'status': 'LOSE',
#        'winOrd': '33',
#        'selections': [{'selId': '31',
#          'str': 'DO',
#          'name_ch': '和其他',
#          'name_en': 'Draw Others'}]},
#       {'str': 'OHN',
#        'status': 'LOSE',
#        'winOrd': '13',
#        'selections': [{'selId': '32',
#          'str': 'HOAN',
#          'name_ch': '主其他(客無入球)',
#          'name_en': 'Home Others (Away No Goal)'}]},
#       {'str': 'OAN',
#        'status': 'LOSE',
#        'winOrd': '27',
#        'selections': [{'selId': '33',
#          'str': 'AOHN',
#          'name_ch': '客其他(主無入球)',
#          'name_en': 'Away Others (Home No Goal)'}]},
#       {'str': '00:05',
#        'status': 'LOSE',
#        'winOrd': '24',
#        'selections': [{'selId': '23',
#          'str': '0:5',
#          'name_ch': '0:5',
#          'name_en': '0:5'}]},
#       {'str': '00:04',
#        'status': 'LOSE',
#        'winOrd': '21',
#        'selections': [{'selId': '20',
#          'str': '0:4',
#          'name_ch': '0:4',
#          'name_en': '0:4'}]},
#       {'str': '01:04',
#        'status': 'LOSE',
#        'winOrd': '22',
#        'selections': [{'selId': '21',
#          'str': '1:4',
#          'name_ch': '1:4',
#          'name_en': '1:4'}]},
#       {'str': '02:04',
#        'status': 'LOSE',
#        'winOrd': '23',
#        'selections': [{'selId': '22',
#          'str': '2:4',
#          'name_ch': '2:4',
#          'name_en': '2:4'}]},
#       {'str': '01:05',
#        'status': 'LOSE',
#        'winOrd': '25',
#        'selections': [{'selId': '24',
#          'str': '1:5',
#          'name_ch': '1:5',
#          'name_en': '1:5'}]},
#       {'str': '02:05',
#        'status': 'LOSE',
#        'winOrd': '26',
#        'selections': [{'selId': '25',
#          'str': '2:5',
#          'name_ch': '2:5',
#          'name_en': '2:5'}]},
#       {'str': 'AO',
#        'status': 'LOSE',
#        'winOrd': '28',
#        'selections': [{'selId': '26',
#          'str': 'AOHS',
#          'name_ch': '客其他(主有入球)',
#          'name_en': 'Away Others (Home Scores)'}]},
#       {'str': '00:00',
#        'status': 'LOSE',
#        'winOrd': '29',
#        'selections': [{'selId': '27',
#          'str': '0:0',
#          'name_ch': '0:0',
#          'name_en': '0:0'}]},
#       {'str': '01:01',
#        'status': 'LOSE',
#        'winOrd': '30',
#        'selections': [{'selId': '28',
#          'str': '1:1',
#          'name_ch': '1:1',
#          'name_en': '1:1'}]},
#       {'str': '02:02',
#        'status': 'LOSE',
#        'winOrd': '31',
#        'selections': [{'selId': '29',
#          'str': '2:2',
#          'name_ch': '2:2',
#          'name_en': '2:2'}]},
#       {'str': '00:02',
#        'status': 'LOSE',
#        'winOrd': '16',
#        'selections': [{'selId': '15',
#          'str': '0:2',
#          'name_ch': '0:2',
#          'name_en': '0:2'}]},
#       {'str': '01:02',
#        'status': 'LOSE',
#        'winOrd': '17',
#        'selections': [{'selId': '16',
#          'str': '1:2',
#          'name_ch': '1:2',
#          'name_en': '1:2'}]},
#       {'str': '00:03',
#        'status': 'LOSE',
#        'winOrd': '18',
#        'selections': [{'selId': '17',
#          'str': '0:3',
#          'name_ch': '0:3',
#          'name_en': '0:3'}]},
#       {'str': '01:03',
#        'status': 'LOSE',
#        'winOrd': '19',
#        'selections': [{'selId': '18',
#          'str': '1:3',
#          'name_ch': '1:3',
#          'name_en': '1:3'}]},
#       {'str': '02:03',
#        'status': 'LOSE',
#        'winOrd': '20',
#        'selections': [{'selId': '19',
#          'str': '2:3',
#          'name_ch': '2:3',
#          'name_en': '2:3'}]},
#       {'str': '05:00',
#        'status': 'LOSE',
#        'winOrd': '10',
#        'selections': [{'selId': '10',
#          'str': '5:0',
#          'name_ch': '5:0',
#          'name_en': '5:0'}]},
#       {'str': '05:01',
#        'status': 'LOSE',
#        'winOrd': '11',
#        'selections': [{'selId': '11',
#          'str': '5:1',
#          'name_ch': '5:1',
#          'name_en': '5:1'}]},
#       {'str': '05:02',
#        'status': 'LOSE',
#        'winOrd': '12',
#        'selections': [{'selId': '12',
#          'str': '5:2',
#          'name_ch': '5:2',
#          'name_en': '5:2'}]},
#       {'str': 'HO',
#        'status': 'LOSE',
#        'winOrd': '14',
#        'selections': [{'selId': '13',
#          'str': 'HOAS',
#          'name_ch': '主其他(客有入球)',
#          'name_en': 'Home Others (Away Scores)'}]},
#       {'str': '00:01',
#        'status': 'LOSE',
#        'winOrd': '15',
#        'selections': [{'selId': '14',
#          'str': '0:1',
#          'name_ch': '0:1',
#          'name_en': '0:1'}]}]}]},
#   {'id': '813794011',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'OOE',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'O',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'O',
#          'name_ch': '單',
#          'name_en': 'Odd'}]},
#       {'str': 'E',
#        'status': 'WIN',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'E',
#          'name_ch': '雙',
#          'name_en': 'Even'}]}]}]},
#   {'id': '813795012',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'TTG',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': '0',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '0',
#          'name_ch': '0',
#          'name_en': '0'}]},
#       {'str': '1',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': '1',
#          'name_ch': '1',
#          'name_en': '1'}]},
#       {'str': '2',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': '2',
#          'name_ch': '2',
#          'name_en': '2'}]},
#       {'str': '3',
#        'status': 'LOSE',
#        'winOrd': '4',
#        'selections': [{'selId': '4',
#          'str': '3',
#          'name_ch': '3',
#          'name_en': '3'}]},
#       {'str': '4',
#        'status': 'LOSE',
#        'winOrd': '5',
#        'selections': [{'selId': '5',
#          'str': '4',
#          'name_ch': '4',
#          'name_en': '4'}]},
#       {'str': '5',
#        'status': 'LOSE',
#        'winOrd': '6',
#        'selections': [{'selId': '6',
#          'str': '5',
#          'name_ch': '5',
#          'name_en': '5'}]},
#       {'str': '6',
#        'status': 'WIN',
#        'winOrd': '7',
#        'selections': [{'selId': '7',
#          'str': '6',
#          'name_ch': '6',
#          'name_en': '6'}]},
#       {'str': '7+',
#        'status': 'LOSE',
#        'winOrd': '8',
#        'selections': [{'selId': '8',
#          'str': '7+',
#          'name_ch': '7+',
#          'name_en': '7+'}]}]}]},
#   {'id': '823749015',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'NTS',
#    'instNo': 1,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊',
#          'name_en': 'Away'}]},
#       {'str': 'N',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': 'N',
#          'name_ch': '無入球',
#          'name_en': 'No Goals'}]}]}]},
#   {'id': '828045015',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'NTS',
#    'instNo': 6,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'WIN',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊',
#          'name_en': 'Away'}]},
#       {'str': 'N',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': 'N',
#          'name_ch': '無入球',
#          'name_en': 'No Goals'}]}]}]},
#   {'id': '828110015',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'NTS',
#    'instNo': 7,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊',
#          'name_en': 'Away'}]},
#       {'str': 'N',
#        'status': 'WIN',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': 'N',
#          'name_ch': '無入球',
#          'name_en': 'No Goals'}]}]}]},
#   {'id': '826155044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 15,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '半場和 & 皇家馬德里全場淨勝剛好[1]球',
#          'name_en': 'First Half to be drawn & Real Madrid to win the match by exactly [1] goal(s)'}]}]}]},
#   {'id': '813797017',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'FGS',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': '206',
#        'status': 'REFUND',
#        'winOrd': '25',
#        'selections': [{'selId': '40',
#          'str': '206',
#          'name_ch': '伊斯拿杜明基斯',
#          'name_en': 'Isra DOMINGUEZ'}]},
#       {'str': '116',
#        'status': 'REFUND',
#        'winOrd': '16',
#        'selections': [{'selId': '38',
#          'str': '116',
#          'name_ch': '魯爾阿辛斯奧',
#          'name_en': 'Raul ASENCIO'}]},
#       {'str': '110',
#        'status': 'REFUND',
#        'winOrd': '10',
#        'selections': [{'selId': '39',
#          'str': '110',
#          'name_ch': '羅倫素艾古亞度',
#          'name_en': 'Lorenzo AGUADO'}]},
#       {'str': '207',
#        'status': 'REFUND',
#        'winOrd': '26',
#        'selections': [{'selId': '30',
#          'str': '207',
#          'name_ch': '比基費蘭迪斯',
#          'name_en': 'Peque FERNANDEZ'}]},
#       {'str': '211',
#        'status': 'REFUND',
#        'winOrd': '30',
#        'selections': [{'selId': '31',
#          'str': '211',
#          'name_ch': '華倫天巴高',
#          'name_en': 'Valentin BARCO'}]},
#       {'str': '213',
#        'status': 'REFUND',
#        'winOrd': '32',
#        'selections': [{'selId': '32',
#          'str': '213',
#          'name_ch': '文奴般奴',
#          'name_en': 'Manu BUENO'}]},
#       {'str': '216',
#        'status': 'REFUND',
#        'winOrd': '35',
#        'selections': [{'selId': '33',
#          'str': '216',
#          'name_ch': '柏度奧迪斯',
#          'name_en': 'Pedro ORTIZ'}]},
#       {'str': '205',
#        'status': 'LOSE',
#        'winOrd': '24',
#        'selections': [{'selId': '34',
#          'str': '205',
#          'name_ch': '伊頓保',
#          'name_en': 'Stanis IDUMBO'}]},
#       {'str': '214',
#        'status': 'REFUND',
#        'winOrd': '33',
#        'selections': [{'selId': '35',
#          'str': '214',
#          'name_ch': '艾拔圖哥拉度',
#          'name_en': 'Alberto COLLADO'}]},
#       {'str': '215',
#        'status': 'REFUND',
#        'winOrd': '34',
#        'selections': [{'selId': '36',
#          'str': '215',
#          'name_ch': '柏保路利華拿',
#          'name_en': 'Pablo RIVERA Cruz'}]},
#       {'str': '204',
#        'status': 'REFUND',
#        'winOrd': '23',
#        'selections': [{'selId': '37',
#          'str': '204',
#          'name_ch': '馬迪奧美積亞',
#          'name_en': 'Mateo MEJIA'}]},
#       {'str': '208',
#        'status': 'REFUND',
#        'winOrd': '27',
#        'selections': [{'selId': '21',
#          'str': '208',
#          'name_ch': '蘇索',
#          'name_en': 'SUSO'}]},
#       {'str': '104',
#        'status': 'LOSE',
#        'winOrd': '4',
#        'selections': [{'selId': '20',
#          'str': '104',
#          'name_ch': '巴謙戴亞斯',
#          'name_en': 'Brahim DIAZ'}]},
#       {'str': '217',
#        'status': 'REFUND',
#        'winOrd': '36',
#        'selections': [{'selId': '22',
#          'str': '217',
#          'name_ch': '艾迪亞柏祖沙',
#          'name_en': 'ADRIA Giner PEDROSA'}]},
#       {'str': '212',
#        'status': 'LOSE',
#        'winOrd': '31',
#        'selections': [{'selId': '23',
#          'str': '212',
#          'name_ch': '荷安盧山齊士',
#          'name_en': 'Juanlu SANCHEZ'}]},
#       {'str': '114',
#        'status': 'REFUND',
#        'winOrd': '14',
#        'selections': [{'selId': '24',
#          'str': '114',
#          'name_ch': '法蘭加西亞',
#          'name_en': 'Fran GARCIA'}]},
#       {'str': '106',
#        'status': 'REFUND',
#        'winOrd': '6',
#        'selections': [{'selId': '25',
#          'str': '106',
#          'name_ch': '艾達古拿',
#          'name_en': 'Arda GULER'}]},
#       {'str': '201',
#        'status': 'LOSE',
#        'winOrd': '20',
#        'selections': [{'selId': '26',
#          'str': '201',
#          'name_ch': '盧克巴基奧',
#          'name_en': 'Dodi LUKEBAKIO'}]},
#       {'str': '102',
#        'status': 'REFUND',
#        'winOrd': '2',
#        'selections': [{'selId': '27',
#          'str': '102',
#          'name_ch': '安迪歷',
#          'name_en': 'ENDRICK Felipe'}]},
#       {'str': '202',
#        'status': 'LOSE',
#        'winOrd': '21',
#        'selections': [{'selId': '29',
#          'str': '202',
#          'name_ch': '艾錫羅美路',
#          'name_en': 'Issac ROMERO'}]},
#       {'str': '219',
#        'status': 'LOSE',
#        'winOrd': '38',
#        'selections': [{'selId': '28',
#          'str': '219',
#          'name_ch': '荷西卡摩拿',
#          'name_en': 'Jose Angel CARMONA'}]},
#       {'str': '113',
#        'status': 'LOSE',
#        'winOrd': '13',
#        'selections': [{'selId': '15',
#          'str': '113',
#          'name_ch': '卡馬雲加',
#          'name_en': 'Eduardo CAMAVINGA'}]},
#       {'str': '103',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '16',
#          'str': '103',
#          'name_ch': '洛迪高高斯',
#          'name_en': 'RODRYGO Silva de Goes'}]},
#       {'str': '107',
#        'status': 'LOSE',
#        'winOrd': '7',
#        'selections': [{'selId': '17',
#          'str': '107',
#          'name_ch': '費達歷高華維迪',
#          'name_en': 'Federico VALVERDE'}]},
#       {'str': '112',
#        'status': 'LOSE',
#        'winOrd': '12',
#        'selections': [{'selId': '18',
#          'str': '112',
#          'name_ch': '曹亞文尼',
#          'name_en': 'Aurelien TCHOUAMENI'}]},
#       {'str': '105',
#        'status': 'LOSE',
#        'winOrd': '5',
#        'selections': [{'selId': '19',
#          'str': '105',
#          'name_ch': '祖迪比寧咸',
#          'name_en': 'Jude BELLINGHAM'}]},
#       {'str': '115',
#        'status': 'LOSE',
#        'winOrd': '15',
#        'selections': [{'selId': '10',
#          'str': '115',
#          'name_ch': '盧卡斯華斯基斯',
#          'name_en': 'LUCAS Vazquez'}]},
#       {'str': '109',
#        'status': 'REFUND',
#        'winOrd': '9',
#        'selections': [{'selId': '11',
#          'str': '109',
#          'name_ch': '莫迪歷',
#          'name_en': 'Luka MODRIC'}]},
#       {'str': '210',
#        'status': 'REFUND',
#        'winOrd': '29',
#        'selections': [{'selId': '12',
#          'str': '210',
#          'name_ch': '沙奧尼古斯',
#          'name_en': 'SAUL NIGUEZ Esclapez'}]},
#       {'str': '218',
#        'status': 'LOSE',
#        'winOrd': '37',
#        'selections': [{'selId': '13',
#          'str': '218',
#          'name_ch': '森比盧干加',
#          'name_en': 'Albert SAMBI LOKONGA'}]},
#       {'str': '118',
#        'status': 'REFUND',
#        'winOrd': '18',
#        'selections': [{'selId': '14',
#          'str': '118',
#          'name_ch': '費蘭特文迪',
#          'name_en': 'Ferland MENDY'}]},
#       {'str': '120',
#        'status': 'LOSE',
#        'winOrd': '19',
#        'selections': [{'selId': '1',
#          'str': '120',
#          'name_ch': '主其他',
#          'name_en': 'Home Others'}]},
#       {'str': '220',
#        'status': 'LOSE',
#        'winOrd': '39',
#        'selections': [{'selId': '2',
#          'str': '220',
#          'name_ch': '客其他',
#          'name_en': 'Away Others'}]},
#       {'str': '000',
#        'status': 'LOSE',
#        'winOrd': '40',
#        'selections': [{'selId': '3',
#          'str': '00',
#          'name_ch': '無首名入球',
#          'name_en': 'No First Scorer'}]},
#       {'str': '111',
#        'status': 'LOSE',
#        'winOrd': '11',
#        'selections': [{'selId': '4',
#          'str': '111',
#          'name_ch': '魯迪格',
#          'name_en': 'Antonio RUDIGER'}]},
#       {'str': '108',
#        'status': 'LOSE',
#        'winOrd': '8',
#        'selections': [{'selId': '5',
#          'str': '108',
#          'name_ch': '丹尼施巴路斯',
#          'name_en': 'Dani CEBALLOS'}]},
#       {'str': '209',
#        'status': 'REFUND',
#        'winOrd': '28',
#        'selections': [{'selId': '6',
#          'str': '209',
#          'name_ch': '捷西斯拿華斯',
#          'name_en': 'JESUS NAVAS'}]},
#       {'str': '117',
#        'status': 'REFUND',
#        'winOrd': '17',
#        'selections': [{'selId': '7',
#          'str': '117',
#          'name_ch': '捷西斯華利祖',
#          'name_en': 'Jesus VALLEJO'}]},
#       {'str': '203',
#        'status': 'REFUND',
#        'winOrd': '22',
#        'selections': [{'selId': '8',
#          'str': '203',
#          'name_ch': '伊恩拿祖',
#          'name_en': 'Kelechi IHEANACHO'}]},
#       {'str': '101',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '9',
#          'str': '101',
#          'name_ch': '基利安麥巴比',
#          'name_en': 'Kylian MBAPPE'}]}]}]},
#   {'id': '826154044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 14,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '西維爾首隊入球 & 皇家馬德里淨勝[2]球或以上 & 開出總角球多於[11.5]球',
#          'name_en': 'Sevilla to score first & Real Madrid to win by [2] goal(s) or more & Over [11.5] corners taken'}]}]}]},
#   {'id': '826145044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 5,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '兩隊均取得入球 & 皇家馬德里淨勝[2]球或以上 & 開出總角球多於[11.5]球',
#          'name_en': 'Both teams to score & Real Madrid to win by [2] goal(s) or more & Over [11.5] corners taken'}]}]}]},
#   {'id': '813791008',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'HFT',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H:H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H:H',
#          'name_ch': 'H:H',
#          'name_en': 'H:H'}]},
#       {'str': 'H:A',
#        'status': 'LOSE',
#        'winOrd': '7',
#        'selections': [{'selId': '2',
#          'str': 'H:A',
#          'name_ch': 'H:A',
#          'name_en': 'H:A'}]},
#       {'str': 'H:D',
#        'status': 'LOSE',
#        'winOrd': '4',
#        'selections': [{'selId': '3',
#          'str': 'H:D',
#          'name_ch': 'H:D',
#          'name_en': 'H:D'}]},
#       {'str': 'A:H',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '4',
#          'str': 'A:H',
#          'name_ch': 'A:H',
#          'name_en': 'A:H'}]},
#       {'str': 'A:A',
#        'status': 'LOSE',
#        'winOrd': '9',
#        'selections': [{'selId': '5',
#          'str': 'A:A',
#          'name_ch': 'A:A',
#          'name_en': 'A:A'}]},
#       {'str': 'A:D',
#        'status': 'LOSE',
#        'winOrd': '6',
#        'selections': [{'selId': '6',
#          'str': 'A:D',
#          'name_ch': 'A:D',
#          'name_en': 'A:D'}]},
#       {'str': 'D:H',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '7',
#          'str': 'D:H',
#          'name_ch': 'D:H',
#          'name_en': 'D:H'}]},
#       {'str': 'D:A',
#        'status': 'LOSE',
#        'winOrd': '8',
#        'selections': [{'selId': '8',
#          'str': 'D:A',
#          'name_ch': 'D:A',
#          'name_en': 'D:A'}]},
#       {'str': 'D:D',
#        'status': 'LOSE',
#        'winOrd': '5',
#        'selections': [{'selId': '9',
#          'str': 'D:D',
#          'name_ch': 'D:D',
#          'name_en': 'D:D'}]}]}]},
#   {'id': '813784001',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'HAD',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊勝',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊勝',
#          'name_en': 'Away'}]},
#       {'str': 'D',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '3',
#          'str': 'D',
#          'name_ch': '和',
#          'name_en': 'Draw'}]}]}]},
#   {'id': '826144044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 4,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '皇家馬德里淨勝[2]球或以上 & 總入球多於[4.5]球 & 開出總角球多於[11.5]球',
#          'name_en': 'Real Madrid to win by [2] goal(s) or more & Over [4.5] goals & Over [11.5] corners taken'}]}]}]},
#   {'id': '813798045',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'FCH',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]}]},
#   {'id': '813796013',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'FTS',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊',
#          'name_en': 'Away'}]},
#       {'str': 'N',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '3',
#          'str': 'N',
#          'name_ch': '無入球',
#          'name_en': 'No Goals'}]}]}]},
#   {'id': '826158044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 18,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '皇家馬德里半場勝[1:0] & 皇家馬德里全場勝[2:1]',
#          'name_en': 'Real Madrid to win [1:0] in the first half & Real Madrid to win [2:1] in the match'}]}]}]},
#   {'id': '826149044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 9,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '半場總入球多於[1.5]球 & 全場總入球多於[4.5]球 & 全場開出總角球多於[12.5]球',
#          'name_en': 'Over [1.5] goals in the first half & Over [4.5] goals in the match & Over [12.5] corners taken in the match'}]}]}]},
#   {'id': '826150044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 10,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '半場總入球少於[1.5]球 & 全場總入球少於[3.5]球 & 全場開出總角球少於[9.5]球',
#          'name_en': 'Under [1.5] goals in the first half & Under [3.5] goals in the match & Under [9.5] corners taken in the match'}]}]}]},
#   {'id': '826153044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 13,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '皇家馬德里首隊入球 & 皇家馬德里半場勝 & 半場總入球多於[2.5]球',
#          'name_en': 'Real Madrid to score first in the match & Real Madrid to win the first half & Over [2.5] goals in the first half'}]}]}]},
#   {'id': '826159044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 19,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '皇家馬德里半場勝[2:0] & 皇家馬德里全場勝[3:0]',
#          'name_en': 'Real Madrid to win [2:0] in the first half & Real Madrid to win [3:0] in the match'}]}]}]},
#   {'id': '828007015',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'NTS',
#    'instNo': 2,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊',
#          'name_en': 'Away'}]},
#       {'str': 'N',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': 'N',
#          'name_ch': '無入球',
#          'name_en': 'No Goals'}]}]}]},
#   {'id': '813788005',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'CHL',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'WIN',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'WIN',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'WIN',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]},
#     {'combinations': [{'str': 'H',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '大',
#          'name_en': 'High'}]},
#       {'str': 'L',
#        'status': 'WIN',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'L',
#          'name_ch': '細',
#          'name_en': 'Low'}]}]}]},
#   {'id': '826157044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 17,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '皇家馬德里全場淨勝[2]球或以上 & 半場總入球多於[1.5]球 & 全場總入球多於[4.5]球',
#          'name_en': 'Real Madrid to win the match by [2] goal(s) or more & Over [1.5] goals in the first half & Over [4.5] goals in the match'}]}]}]},
#   {'id': '826143044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 3,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '皇家馬德里半場勝[3:0] & 皇家馬德里全場勝[4:0]',
#          'name_en': 'Real Madrid to win [3:0] in the first half & Real Madrid to win [4:0] in the match'}]}]}]},
#   {'id': '813785002',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'FHA',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊勝',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊勝',
#          'name_en': 'Away'}]},
#       {'str': 'D',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '3',
#          'str': 'D',
#          'name_ch': '和',
#          'name_en': 'Draw'}]}]}]},
#   {'id': '826141044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 1,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '基利安麥巴比首名入球 & 半場總入球多於[2.5]球',
#          'name_en': 'Kylian MBAPPE to score first in the match & Over [2.5] goals in the first half'}]}]}]},
#   {'id': '826160044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 20,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '半場和[1:1] & 皇家馬德里全場勝[4:1]',
#          'name_en': 'First half to be drawn [1:1] & Real Madrid to win [4:1] in the match'}]}]}]},
#   {'id': '826147044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 7,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '兩隊均取得入球 & 西維爾勝 & 開出總角球少於[9.5]球',
#          'name_en': 'Both teams to score & Sevilla to win & Under [9.5] corners taken'}]}]}]},
#   {'id': '813793010',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'FCS',
#    'instNo': 0,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': '01:00',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '1:0',
#          'name_ch': '1:0',
#          'name_en': '1:0'}]},
#       {'str': '02:00',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': '2:0',
#          'name_ch': '2:0',
#          'name_en': '2:0'}]},
#       {'str': '02:01',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': '2:1',
#          'name_ch': '2:1',
#          'name_en': '2:1'}]},
#       {'str': '03:00',
#        'status': 'LOSE',
#        'winOrd': '4',
#        'selections': [{'selId': '4',
#          'str': '3:0',
#          'name_ch': '3:0',
#          'name_en': '3:0'}]},
#       {'str': '03:01',
#        'status': 'WIN',
#        'winOrd': '5',
#        'selections': [{'selId': '5',
#          'str': '3:1',
#          'name_ch': '3:1',
#          'name_en': '3:1'}]},
#       {'str': '03:02',
#        'status': 'LOSE',
#        'winOrd': '6',
#        'selections': [{'selId': '6',
#          'str': '3:2',
#          'name_ch': '3:2',
#          'name_en': '3:2'}]},
#       {'str': '04:00',
#        'status': 'LOSE',
#        'winOrd': '7',
#        'selections': [{'selId': '7',
#          'str': '4:0',
#          'name_ch': '4:0',
#          'name_en': '4:0'}]},
#       {'str': '04:01',
#        'status': 'LOSE',
#        'winOrd': '8',
#        'selections': [{'selId': '8',
#          'str': '4:1',
#          'name_ch': '4:1',
#          'name_en': '4:1'}]},
#       {'str': '04:02',
#        'status': 'LOSE',
#        'winOrd': '9',
#        'selections': [{'selId': '9',
#          'str': '4:2',
#          'name_ch': '4:2',
#          'name_en': '4:2'}]},
#       {'str': '00:00',
#        'status': 'LOSE',
#        'winOrd': '29',
#        'selections': [{'selId': '27',
#          'str': '0:0',
#          'name_ch': '0:0',
#          'name_en': '0:0'}]},
#       {'str': '00:04',
#        'status': 'LOSE',
#        'winOrd': '21',
#        'selections': [{'selId': '20',
#          'str': '0:4',
#          'name_ch': '0:4',
#          'name_en': '0:4'}]},
#       {'str': '01:04',
#        'status': 'LOSE',
#        'winOrd': '22',
#        'selections': [{'selId': '21',
#          'str': '1:4',
#          'name_ch': '1:4',
#          'name_en': '1:4'}]},
#       {'str': '02:04',
#        'status': 'LOSE',
#        'winOrd': '23',
#        'selections': [{'selId': '22',
#          'str': '2:4',
#          'name_ch': '2:4',
#          'name_en': '2:4'}]},
#       {'str': '00:05',
#        'status': 'LOSE',
#        'winOrd': '24',
#        'selections': [{'selId': '23',
#          'str': '0:5',
#          'name_ch': '0:5',
#          'name_en': '0:5'}]},
#       {'str': '01:05',
#        'status': 'LOSE',
#        'winOrd': '25',
#        'selections': [{'selId': '24',
#          'str': '1:5',
#          'name_ch': '1:5',
#          'name_en': '1:5'}]},
#       {'str': '02:05',
#        'status': 'LOSE',
#        'winOrd': '26',
#        'selections': [{'selId': '25',
#          'str': '2:5',
#          'name_ch': '2:5',
#          'name_en': '2:5'}]},
#       {'str': 'AO',
#        'status': 'LOSE',
#        'winOrd': '28',
#        'selections': [{'selId': '26',
#          'str': 'AOHS',
#          'name_ch': '客其他(主有入球)',
#          'name_en': 'Away Others (Home Scores)'}]},
#       {'str': '01:01',
#        'status': 'LOSE',
#        'winOrd': '30',
#        'selections': [{'selId': '28',
#          'str': '1:1',
#          'name_ch': '1:1',
#          'name_en': '1:1'}]},
#       {'str': '02:02',
#        'status': 'LOSE',
#        'winOrd': '31',
#        'selections': [{'selId': '29',
#          'str': '2:2',
#          'name_ch': '2:2',
#          'name_en': '2:2'}]},
#       {'str': '03:03',
#        'status': 'LOSE',
#        'winOrd': '32',
#        'selections': [{'selId': '30',
#          'str': '3:3',
#          'name_ch': '3:3',
#          'name_en': '3:3'}]},
#       {'str': 'DO',
#        'status': 'LOSE',
#        'winOrd': '33',
#        'selections': [{'selId': '31',
#          'str': 'DO',
#          'name_ch': '和其他',
#          'name_en': 'Draw Others'}]},
#       {'str': 'OHN',
#        'status': 'LOSE',
#        'winOrd': '13',
#        'selections': [{'selId': '32',
#          'str': 'HOAN',
#          'name_ch': '主其他(客無入球)',
#          'name_en': 'Home Others (Away No Goal)'}]},
#       {'str': 'OAN',
#        'status': 'LOSE',
#        'winOrd': '27',
#        'selections': [{'selId': '33',
#          'str': 'AOHN',
#          'name_ch': '客其他(主無入球)',
#          'name_en': 'Away Others (Home No Goal)'}]},
#       {'str': '05:00',
#        'status': 'LOSE',
#        'winOrd': '10',
#        'selections': [{'selId': '10',
#          'str': '5:0',
#          'name_ch': '5:0',
#          'name_en': '5:0'}]},
#       {'str': '05:01',
#        'status': 'LOSE',
#        'winOrd': '11',
#        'selections': [{'selId': '11',
#          'str': '5:1',
#          'name_ch': '5:1',
#          'name_en': '5:1'}]},
#       {'str': '05:02',
#        'status': 'LOSE',
#        'winOrd': '12',
#        'selections': [{'selId': '12',
#          'str': '5:2',
#          'name_ch': '5:2',
#          'name_en': '5:2'}]},
#       {'str': 'HO',
#        'status': 'LOSE',
#        'winOrd': '14',
#        'selections': [{'selId': '13',
#          'str': 'HOAS',
#          'name_ch': '主其他(客有入球)',
#          'name_en': 'Home Others (Away Scores)'}]},
#       {'str': '00:01',
#        'status': 'LOSE',
#        'winOrd': '15',
#        'selections': [{'selId': '14',
#          'str': '0:1',
#          'name_ch': '0:1',
#          'name_en': '0:1'}]},
#       {'str': '00:02',
#        'status': 'LOSE',
#        'winOrd': '16',
#        'selections': [{'selId': '15',
#          'str': '0:2',
#          'name_ch': '0:2',
#          'name_en': '0:2'}]},
#       {'str': '01:02',
#        'status': 'LOSE',
#        'winOrd': '17',
#        'selections': [{'selId': '16',
#          'str': '1:2',
#          'name_ch': '1:2',
#          'name_en': '1:2'}]},
#       {'str': '00:03',
#        'status': 'LOSE',
#        'winOrd': '18',
#        'selections': [{'selId': '17',
#          'str': '0:3',
#          'name_ch': '0:3',
#          'name_en': '0:3'}]},
#       {'str': '01:03',
#        'status': 'LOSE',
#        'winOrd': '19',
#        'selections': [{'selId': '18',
#          'str': '1:3',
#          'name_ch': '1:3',
#          'name_en': '1:3'}]},
#       {'str': '02:03',
#        'status': 'LOSE',
#        'winOrd': '20',
#        'selections': [{'selId': '19',
#          'str': '2:3',
#          'name_ch': '2:3',
#          'name_en': '2:3'}]}]}]},
#   {'id': '826151044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 11,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '半場開出總角球多於[6.5]球 & 全場開出總角球多於[13.5]球',
#          'name_en': 'Over [6.5] corners taken in the first half & Over [13.5] corners taken in the match'}]}]}]},
#   {'id': '826142044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 2,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '基利安麥巴比首名入球 & 總入球多於[4.5]球',
#          'name_en': 'Kylian MBAPPE to score first & Over [4.5] goals'}]}]}]},
#   {'id': '826148044',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'SGA',
#    'instNo': 8,
#    'name_ch': None,
#    'name_en': None,
#    'lines': [{'combinations': [{'str': '01',
#        'status': 'LOSE',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': '',
#          'name_ch': '半場和 & 全場兩隊均取得入球',
#          'name_en': 'First Half to be drawn & Both teams to score in the match'}]}]}]},
#   {'id': '828024015',
#    'status': 'PAYOUTSTARTED',
#    'oddsType': 'NTS',
#    'instNo': 3,
#    'name_ch': '',
#    'name_en': '',
#    'lines': [{'combinations': [{'str': 'H',
#        'status': 'WIN',
#        'winOrd': '1',
#        'selections': [{'selId': '1',
#          'str': 'H',
#          'name_ch': '主隊',
#          'name_en': 'Home'}]},
#       {'str': 'A',
#        'status': 'LOSE',
#        'winOrd': '2',
#        'selections': [{'selId': '2',
#          'str': 'A',
#          'name_ch': '客隊',
#          'name_en': 'Away'}]},
#       {'str': 'N',
#        'status': 'LOSE',
#        'winOrd': '3',
#        'selections': [{'selId': '3',
#          'str': 'N',
#          'name_ch': '無入球',
#          'name_en': 'No Goals'}]}]}]}],
#  'additionalResults': []}

# %%
match_results = match_records_scraper.get_match_results_by_batch(
    match_id_list=["50039609", "50039827"],
)
len(match_results)
# Out:
# 2

# %%
match_results[1].keys()
# Out:
# dict_keys(['id', 'foPools', 'additionalResults'])

# %%
with open("../../../data/sample_data/match_results_sample_20250124.json", "w") as f:
    f.write(json.dumps(match_records_list))

# %% [markdown]
# ## 4. Test Query for Match Odds

# %%
match_odds = match_records_scraper.get_match_odds_by_batch(
    match_id_list=["50039609", "50039827"],
)
len(match_odds)
# Out:
# 2

# %%
match_odds[1].keys()
# Out:
# dict_keys(['id', 'updateAt', 'statusUpdatedAt', 'foPools'])

# %%
with open("../../../data/sample_data/match_odds_sample_20250124.json", "w") as f:
    f.write(json.dumps(match_records_list))

# %% [markdown]
# ## 5. Test Query for Live Match Odds

# %%
live_match_odds_scraper = LiveMatchScraper()
live_match_odds = live_match_odds_scraper.get_live_matches_info_by_match_ids(
    match_id_list=None,
)

# %%
len(live_match_odds)
# Out:
# 139

# %%
live_match_odds[0].keys()
# Out:
# dict_keys(['id', 'frontEndId', 'matchDate', 'kickOffTime', 'status', 'updateAt', 'sequence', 'esIndicatorEnabled', 'homeTeam', 'awayTeam', 'tournament', 'isInteractiveServiceAvailable', 'inplayDelay', 'venue', 'tvChannels', 'liveEvents', 'featureStartTime', 'featureMatchSequence', 'poolInfo', 'runningResult', 'runningResultExtra', 'adminOperation', 'foPools'])

# %%
for match in live_match_odds:
    print(f"{match['homeTeam']['name_ch']} v.s. {match['awayTeam']['name_ch']}")
# Out:
# 艾雷恩 v.s. 艾杜哈尼
# 阿爾克馬爾 v.s. 羅馬
# 費倫巴治 v.s. 里昂
# 賀芬咸 v.s. 熱刺
# 波圖 v.s. 奧林比亞高斯
# 波杜基林特 v.s. 特拉維夫馬卡比
# 馬模 v.s. 川迪
# 卡拉巴克 v.s. 布加勒斯特星隊
# 柏辛域陀尼亞 v.s. 安德列治
# 皇家馬德里女足 v.s. 皇家蘇斯達女足
# 曼聯 v.s. 格拉斯哥流浪
# 拉素 v.s. 皇家蘇斯達
# 艾夫斯堡 v.s. 尼斯
# 法蘭克福 v.s. 費倫斯華路士
# 盧多格德斯 v.s. 米迪蘭特
# PAOK v.s. 布拉格斯拉維亞
# RFS v.s. 阿積士
# 聖基萊斯聯 v.s. 布拉加
# 域斯咸 v.s. 伯明翰
# 秘魯U20 v.s. 巴拉圭U20
# 諾羅斯特 v.s. 保地花高SP
# 聖貝拿度 v.s. 米拉索
# 葛度爾古斯 v.s. 羅沙里奧中央
# 堤格雷 v.s. 沙士菲
# 聖保羅 v.s. 古蘭尼
# 委內瑞拉U20 v.s. 智利U20
# 防衛者 v.s. 班菲特
# 紐維爾舊生 v.s. 利華達維亞獨立
# 拉魯斯 v.s. 萊斯查
# 墨爾本勝利女足 v.s. FC悉尼女足
# 墨爾本勝利 v.s. FC悉尼
# 艾沙瑪 v.s. 烏姆沙拉爾
# 艾華卡拉 v.s. 多哈艾阿拉比
# 格雷特霍夫 v.s. 凱沙羅頓
# 馬格德堡 v.s. 布倫瑞克
# 荷華高斯 v.s. 烏德勒支
# 迪加史卓普 v.s. 安曼
# 丹保殊 v.s. 奧斯
# FC燕豪芬 v.s. 甘堡爾
# 洛達 v.s. 烏德勒支青年隊
# 維迪斯 v.s. 多德勒支
# 禾寧丹 v.s. 馬斯特里赫特
# 巴斯蒂亞 v.s. FC波城
# 卡昂 v.s. 甘岡
# 拉瓦勒 v.s. 特魯瓦
# 馬堤古斯 v.s. 艾米恩斯
# 梅斯 v.s. 格勒諾布爾
# 羅德茲 v.s. 阿些斯奧
# 禾夫斯堡 v.s. 基爾
# 艾爾切 v.s. 伊巴
# 拖連奴 v.s. 卡利亞里
# 歐塞爾 v.s. 聖伊天
# 聖圖爾登 v.s. 安特衛普
# 紐波特郡 v.s. 史雲頓
# 拉斯彭馬斯 v.s. 奧沙辛拿
# 錫菲聯 v.s. 侯城
# 巴拉卡斯中央 v.s. 競賽會
# 阿洛卡 v.s. 摩里倫斯
# 柏利斯天奴 v.s. 奧達斯
# 獨立隊 v.s. 沙米恩圖
# 貝格拉諾 v.s. 颶風隊
# 聖馬田聖祖安 v.s. 圖庫曼體育會
# 聖路易斯體育會 v.s. 尼卡沙
# 迪祖亞拿 v.s. 克雷塔羅
# FC馬薩特蘭 v.s. 托盧卡
# 拉巴斯體育會 v.s. 哥雷卡米諾斯
# 威靈頓鳳凰 v.s. 中岸水手
# 紐卡素噴射機 v.s. 珀斯光輝
# 西悉尼流浪者女足 v.s. 墨爾本城女足
# 阿德萊德聯女足 v.s. 西部聯女足
# FC麥克阿瑟 v.s. 墨爾本城
# 紐卡素噴射機女足 v.s. 坎培拉聯女足
# 史浩克04 v.s. 紐倫堡
# 科隆 v.s. 艾華斯堡
# 卡爾斯魯厄 v.s. 杜塞爾多夫
# 馬略卡 v.s. 貝迪斯
# 蒙彼利埃女足 v.s. 勒哈弗爾女足
# 科木 v.s. 阿特蘭大
# 多蒙特 v.s. 雲達不來梅
# 弗賴堡 v.s. 拜仁慕尼黑
# RB萊比錫 v.s. 利華古遜
# 奧格斯堡 v.s. 海登咸
# 緬恩斯 v.s. 史特加
# 利物浦 v.s. 葉士域治
# 般尼茅夫 v.s. 諾定咸森林
# 白禮頓 v.s. 愛華頓
# 修咸頓 v.s. 紐卡素
# 狼隊 v.s. 阿仙奴
# 些路迪 v.s. 登地
# 鴨巴甸 v.s. 聖美倫
# 赫斯 v.s. 基爾馬諾克
# 羅斯郡 v.s. 喜伯年
# 聖莊士東 v.s. 馬瑟韋爾
# 馬德里體育會 v.s. 維拉利爾
# 法馬利卡奧 v.s. 艾馬多拉
# 法倫斯 v.s. 里奧艾維
# 泰斯達 v.s. 阿積士青年隊
# 摩納哥 v.s. 雷恩
# 拿玻里 v.s. 祖雲達斯
# 曼城 v.s. 車路士
# 西維爾 v.s. 愛斯賓奴
# 慕遜加柏 v.s. 波琴
# 燕豪芬 v.s. NAC
# 斯特拉斯堡 v.s. 里爾
# AC卡薩比亞 v.s. 賓菲加
# 哈化柏林 v.s. 漢堡
# 安玻里 v.s. 博洛尼亞
# 華拉度列 v.s. 皇家馬德里
# 格羅寧根 v.s. 海倫芬
# 巴黎聖日耳門 v.s. 蘭斯
# 士砵亭 v.s. 國民隊
# 西悉尼流浪者 v.s. 奧克蘭FC
# 中岸水手女足 v.s. 威靈頓鳳凰女足
# 珀斯光輝女足 v.s. 布里斯班獅吼女足
# 幸運薛達 v.s. 施禾利
# 精英隊 v.s. 海牙
# AC米蘭 v.s. 帕爾馬
# 登地聯 v.s. 格拉斯哥流浪
# 達斯泰特 v.s. 柏達邦
# 漢諾威 v.s. 普斯辛蒙斯達
# 烏爾姆 v.s. 雷根斯堡
# 華歷簡奴 v.s. 基羅納
# 華域克 v.s. 威廉二世
# 水晶宮 v.s. 賓福特
# 勒哈弗爾 v.s. 比斯特
# 艾斯杜尼 v.s. 甘馬雷斯
# 靴蒙特 v.s. 阿爾克馬爾青年隊
# 朗斯 v.s. 昂熱
# 圖盧茲 v.s. 蒙彼利埃
# 阿士東維拉 v.s. 韋斯咸
# 聖保利 v.s. 柏林聯
# 萊切 v.s. 國際米蘭
# 畢爾包 v.s. 雷加利斯
# 巴塞隆拿 v.s. 華倫西亞
# 威尼斯 v.s. 維羅納
# 燕豪芬青年隊 v.s. 芬洛
# 熱拿亞 v.s. 蒙沙
# 艾拉維斯 v.s. 切爾達
# AVS v.s. 基維辛迪

# %%
with open("../../../data/sample_data/live_matches_sample_20250124.json", "w") as f:
    f.write(json.dumps(match_records_list))
