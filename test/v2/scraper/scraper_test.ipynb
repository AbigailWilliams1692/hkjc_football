# %%
# Import Libraries
## Standard Libraries
import datetime
import os
import sys
import requests

## Third-Party Libraries
import numpy as np
import pandas as pd

## Local Libraries
from v2.scraper import MatchOddsScraper, MatchResultsScraper, TeamIDScraper

# %% [markdown]
# ## 1. Test Query for Historical Matches

# %%
match_results_scraper = MatchResultsScraper()
match_results = match_results_scraper.get_historical_matches(
    start_date=datetime.date(2025, 1, 1),
    end_date=datetime.date(2025, 1, 5),
    team_id="50000008",
)

# %%
match_results
# Out:
# {'data': {'timeOffset': {'fb': 0},
#   'matchNumByDate': {'total': 1},
#   'matches': [{'id': '50040218',
#     'status': 'INPLAYMATCHENDED',
#     'frontEndId': 'FB5784',
#     'matchDayOfWeek': '',
#     'matchNumber': '',
#     'matchDate': '2025-01-04+08:00',
#     'kickOffTime': '2025-01-04T03:00:00.000+08:00',
#     'sequence': '1.1735930800.25.Italian Super Cup                                                                                                               .0.01.Juventus                                                                                                                        .000',
#     'homeTeam': {'id': '50001741', 'name_en': 'Juventus', 'name_ch': '祖雲達斯'},
#     'awayTeam': {'id': '50000008', 'name_en': 'AC Milan', 'name_ch': 'AC米蘭'},
#     'tournament': {'code': 'ISC',
#      'name_en': 'Italian Super Cup',
#      'name_ch': '意大利超級盃'},
#     'results': [{'homeResult': 1,
#       'awayResult': 0,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 2,
#       'resultType': 1,
#       'sequence': 226},
#      {'homeResult': 1,
#       'awayResult': 0,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 3,
#       'resultType': 1,
#       'sequence': 227},
#      {'homeResult': 1,
#       'awayResult': 1,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 1,
#       'sequence': 228},
#      {'homeResult': 1,
#       'awayResult': 2,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 1,
#       'sequence': 229},
#      {'homeResult': 1,
#       'awayResult': 2,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 5,
#       'resultType': 1,
#       'sequence': 230},
#      {'homeResult': 0,
#       'awayResult': 1,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 2,
#       'resultType': 2,
#       'sequence': 231},
#      {'homeResult': 0,
#       'awayResult': 2,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 2,
#       'resultType': 2,
#       'sequence': 232},
#      {'homeResult': 0,
#       'awayResult': 3,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 2,
#       'resultType': 2,
#       'sequence': 233},
#      {'homeResult': 1,
#       'awayResult': 3,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 2,
#       'resultType': 2,
#       'sequence': 234},
#      {'homeResult': 1,
#       'awayResult': 3,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 3,
#       'resultType': 2,
#       'sequence': 235},
#      {'homeResult': 1,
#       'awayResult': 4,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 236},
#      {'homeResult': 1,
#       'awayResult': 5,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 237},
#      {'homeResult': 2,
#       'awayResult': 5,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 238},
#      {'homeResult': 3,
#       'awayResult': 5,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 239},
#      {'homeResult': 3,
#       'awayResult': 6,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 240},
#      {'homeResult': 3,
#       'awayResult': 7,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 241},
#      {'homeResult': 4,
#       'awayResult': 7,
#       'resultConfirmType': 1,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 242},
#      {'homeResult': 5,
#       'awayResult': 7,
#       'resultConfirmType': 1,
#       'payoutConfirmed': True,
#       'stageId': 4,
#       'resultType': 2,
#       'sequence': 243},
#      {'homeResult': 5,
#       'awayResult': 7,
#       'resultConfirmType': 5,
#       'payoutConfirmed': True,
#       'stageId': 5,
#       'resultType': 2,
#       'sequence': 244},
#      {'homeResult': 0,
#       'awayResult': 0,
#       'resultConfirmType': 1,
#       'payoutConfirmed': True,
#       'stageId': 3,
#       'resultType': 4,
#       'sequence': 245},
#      {'homeResult': 0,
#       'awayResult': 0,
#       'resultConfirmType': 1,
#       'payoutConfirmed': True,
#       'stageId': 5,
#       'resultType': 4,
#       'sequence': 246}],
#     'poolInfo': {'payoutRefundPools': ['SGA',
#       'NTS',
#       'HAD',
#       'FHL',
#       'FGS',
#       'HHA',
#       'FTS',
#       'FCH',
#       'TTG',
#       'HFT',
#       'CHL',
#       'OOE',
#       'HDC',
#       'FHA',
#       'CRS',
#       'HIL',
#       'FCS'],
#      'refundPools': [],
#      'ntsInfo': [],
#      'entInfo': [],
#      'definedPools': ['SGA',
#       'NTS',
#       'SGA',
#       'NTS',
#       'HAD',
#       'SGA',
#       'FHL',
#       'SGA',
#       'FGS',
#       'SGA',
#       'HHA',
#       'FTS',
#       'NTS',
#       'FCH',
#       'SGA',
#       'SGA',
#       'SGA',
#       'TTG',
#       'SGA',
#       'SGA',
#       'HFT',
#       'SGA',
#       'SGA',
#       'CHL',
#       'SGA',
#       'SGA',
#       'OOE',
#       'SGA',
#       'SGA',
#       'SGA',
#       'HDC',
#       'SGA',
#       'FHA',
#       'CRS',
#       'SGA',
#       'SGA',
#       'NTS',
#       'HIL',
#       'FCS']}}]}}
